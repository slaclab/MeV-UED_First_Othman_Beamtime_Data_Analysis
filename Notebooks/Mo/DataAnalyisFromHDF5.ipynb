# %%
# Load the data from the Streaking  preprocessing .h5 file
# Sunnyvale, Yusong, 06/15/2025

# %%
import os
import sys
sys.path.append('/sdf/data/lcls/ds/ued_testfac/scratch/python_packages')
import time
import numpy as np
import h5py
import matplotlib as mpl
import matplotlib.pyplot as plt
import configparser
import argparse
import scipy.ndimage.measurements as smt
import glob
from scipy.ndimage import gaussian_filter as gf
from scipy.optimize import curve_fit
from scipy.special import erf
from psana import DataSource
from numba import jit, njit
from ued_LCLSII_DAQ_utilities import *
from UEDePixTools import *
from tqdm import tqdm
from PIL import Image

# %matplotlib widget

# %%
# Define the function with two Gaussians
def center_of_mass(Distribution,opetor): # Define Center of Mass function 
    output = np.sum(opetor*Distribution,axis=0)/np.sum(Distribution,axis=0)
    return output
    
def gaussian(x, amp, mean, sigma): # Define the Gaussian function
    return amp * np.exp(-(x - mean)**2 / (2 * sigma**2))

def error_function(x, a, b, c,y0): # Define the error function model
    return a * erf(b * (x - c))+y0

# %%
# Check a single and pring out keys
exp = 'ued1011086'
run = 26

# Zero-pad the run number to match filename convention
run_str = f"{run:04d}"  # gives '0026'

# Build the path pattern
pattern = f"/sdf/data/lcls/ds/ued/{exp}/hdf5/smalldata/{exp}_Run{run_str}_part*.h5"

# Get all matching part files
file_list = sorted(glob.glob(pattern))

print(f"Found {len(file_list)} part files:")
for f in file_list:
    print("  ", f)

# Open each file (example: just reading one dataset from each)
for fname in file_list:
    with h5py.File(fname, 'r') as raw:
        print(f"\n{fname} contains datasets:")
        print(list(raw.keys()))
# Out:
# Found 32 part files:
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part0.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part1.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part10.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part11.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part12.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part13.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part14.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part15.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part16.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part17.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part18.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part19.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part2.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part20.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part21.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part22.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part23.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part24.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part25.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part26.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part27.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part28.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part29.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part3.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part30.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part31.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part4.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part5.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part6.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part7.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part8.h5
#    /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part9.h5
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part0.h5 contains datasets:
# ['epixquad', 'scan', 'timestamp', 'timing']
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part1.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part10.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part11.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part12.h5 contains datasets:
# ['epixquad', 'scan', 'timestamp', 'timing']
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part13.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part14.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part15.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part16.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part17.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part18.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part19.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part2.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part20.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part21.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part22.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part23.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part24.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part25.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part26.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part27.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part28.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part29.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part3.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part30.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part31.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part4.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part5.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part6.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part7.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part8.h5 contains datasets:
# []
#
# /sdf/data/lcls/ds/ued/ued1011086/hdf5/smalldata/ued1011086_Run0026_part9.h5 contains datasets:
# []

# %%
runs = np.array([run])
print('Load .h5 run of'+str(runs))
tic = time.time()
for i_run, run in enumerate(runs):
    hf = h5py.File("/sdf/scratch/lcls/ds/ued/%s/scratch/preproc/v2/run_%i.h5" % (exp, run), 'r')
    print(f'Loading run: {run}')

    # Extract the .h5 infors
    timestamp  = np.argsort(np.array(hf.get('timestamp')))
    shot_id    = np.arange(0,len(timestamp))[timestamp]
    scan_var_1 = np.array(hf.get('step_value'))[timestamp].flatten() # the photon energy
    img_inte_1 = np.array(hf.get('img_inte_1'))[timestamp]
    img_inte_2 = np.array(hf.get('img_inte_2'))[timestamp]
    img_com_1  = np.array(hf.get('img_com_1'))[timestamp]
    img_com_2  = np.array(hf.get('img_com_2'))[timestamp]
    img_cut    = np.array(hf.get('img_cut'))[timestamp]

    if i_run == 0:
        timestamp_runs  = timestamp
        shot_id_runs    = shot_id
        scan_var_1_runs = scan_var_1
        img_inte_1_runs = img_inte_1
        img_inte_2_runs = img_inte_2
        img_com_1_runs  = img_com_1
        img_com_2_runs  = img_com_2
        img_cut_runs    = img_cut

    else:
        timestamp_runs  = np.concatenate((timestamp_runs,timestamp),axis=0)
        shot_id_runs    = np.concatenate((shot_id_runs,shot_id),axis=0)
        img_inte_1_runs = np.concatenate((img_inte_1_runs,img_inte_1),axis=0)
        img_inte_2_runs = np.concatenate((img_inte_2_runs,img_inte_2),axis=0)
        scan_var_1_runs = np.concatenate((scan_var_1_runs,scan_var_1),axis=0)
        img_com_1_runs  = np.concatenate((img_com_1_runs,img_com_1),axis=0)
        img_com_2_runs  = np.concatenate((img_com_2_runs,img_com_2),axis=0)
        img_cut_runs    = np.concatenate((img_cut_runs,img_cut),axis=0)

toc = time.time()
print(f'Load time : {np.round(toc-tic)} seconds')
delayss = np.unique(scan_var_1_runs) # The scan
print('Total steps of PV values are: '+str(delayss.shape[0]))
img_cut_shape = np.shape(img_cut_runs)
# Out:
# Load .h5 run of[26]
# Loading run: 26
# Load time : 0.0 seconds
# Total steps of PV values are: 38

# %%
# Plot the single short images

# %%
plt.figure()
plt.suptitle('ePix, Run-'+str(run)+', '+str(exp))
plt.plot(scan_var_1_runs[(img_com_2_runs>5)&(img_com_2_runs<60)], img_com_2_runs[(img_com_2_runs>5)&(img_com_2_runs<60)],'.')
plt.xlabel('Scan PV values');plt.ylabel('CoM of the ebeam pixels');
plt.title('CoM of ebeam at each shot');
plt.tight_layout()
plt.show()

# %%
# Averaging the ingegrated signal at each PV scan vales
img_runs_ave = []
img_inte_2_runs_ave = []
img_inte_2_runs_coms_ave  = []
for i_delay, delay in enumerate(delayss):
    flt_step = (scan_var_1_runs == delay)&(img_com_2_runs>0)&(img_com_2_runs<60)
    img_runs_ave.append(img_cut[flt_step].mean(axis=0))
    img_inte_2_runs_ave.append(img_inte_2_runs[flt_step].mean(axis=0)) # ave trace
    img_inte_2_runs_coms_ave.append(img_com_2_runs[flt_step].mean())
img_inte_2_runs_coms_ave = np.array(img_inte_2_runs_coms_ave)
img_inte_2_runs_ave      = np.array(img_inte_2_runs_ave)
img_runs_ave             = np.array(img_runs_ave)

# %%
plt.figure(figsize=(12,8))
plt.suptitle('ePix, Run-'+str(run)+', '+str(exp)+', averaged images at each PV valies')
i_subplot = 1
for i_delay, delay in enumerate(delayss):
    if i_delay%5==0:
        plt.subplot(4,6,i_subplot)
        plt.pcolormesh(img_runs_ave[i_delay],cmap='jet')
        i_subplot = i_subplot + 1
        plt.cmap = [0,70000]
        plt.xlabel('Pixel-X')
        plt.ylabel('Pixel-Y')
        plt.title('Stage at '+str(delay)+' mm')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(9,7))
plt.suptitle('ePix, Run-'+str(run)+', '+str(exp))

plt.subplot(2,2,1)
plt.plot(scan_var_1_runs)
plt.xlabel('Img num');plt.ylabel('Scan values');plt.title('Scan PV values');

plt.subplot(2,2,2)
plt.plot(delayss,'-')
plt.xlabel('Img num');plt.ylabel('Scan values');plt.title('Sorted scan PV values')

plt.subplot(2,2,3)
plt.pcolormesh(np.arange(np.shape(img_inte_2_runs)[1]),delayss,img_inte_2_runs_ave,cmap='inferno')
plt.xlim([0,img_cut_shape[1]-1])
plt.title('Integrated signal on the streaking axis');
plt.xlabel('Pixel');plt.ylabel('Scan PV');# plt.colorbar()

plt.subplot(2,2,4)
plt.plot(img_inte_2_runs_coms_ave,delayss)
plt.xlim([0,img_cut_shape[1]-1])
plt.xlabel('Pixel');plt.ylabel('Scan PV');
plt.title('Integrated CoM on the streaking axis');

plt.tight_layout()
plt.show()
